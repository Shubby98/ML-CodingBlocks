# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
stock_X = pd.read_csv("Train/x_train.csv")
stock_Y = pd.read_csv("Train/y_train.csv")

print(stock_X.shape)
print(stock_Y.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
print(stock_X.tail(6))
stock_Y.tail(6)
# Out:
#         High
# 1251  796.68
# 1252  793.32
# 1253  792.74
# 1254  797.86
# 1255  794.23
# 1256  785.93
#         High
# 1251  793.32
# 1252  792.74
# 1253  797.86
# 1254  794.23
# 1255  785.93
# 1256  782.78

# %%
plt.figure(figsize = (13,8))
plt.plot(stock_X)
plt.grid()

# %%
i = 1230
stock_X['High'][i:i+40]
# Out:
# 1230    769.70
# 1231    776.96
# 1232    768.28
# 1233    765.00
# 1234    779.53
# 1235    778.50
# 1236    772.99
# 1237    759.85
# 1238    754.00
# 1239    763.90
# 1240    768.83
# 1241    771.36
# 1242    778.18
# 1243    789.43
# 1244    791.25
# 1245    804.38
# 1246    804.00
# 1247    803.00
# 1248    800.86
# 1249    797.66
# 1250    798.65
# 1251    796.68
# 1252    793.32
# 1253    792.74
# 1254    797.86
# 1255    794.23
# 1256    785.93
# Name: High, dtype: float64
