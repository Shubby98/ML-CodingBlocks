# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv("Train/Train_Data.csv")

# %%
dataframe.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 81 columns):
# Id               1100 non-null int64
# MSSubClass       1100 non-null int64
# MSZoning         1100 non-null object
# LotFrontage      908 non-null float64
# LotArea          1100 non-null int64
# Street           1100 non-null object
# Alley            69 non-null object
# LotShape         1100 non-null object
# LandContour      1100 non-null object
# Utilities        1100 non-null object
# LotConfig        1100 non-null object
# LandSlope        1100 non-null object
# Neighborhood     1100 non-null object
# Condition1       1100 non-null object
# Condition2       1100 non-null object
# BldgType         1100 non-null object
# HouseStyle       1100 non-null object
# OverallQual      1100 non-null int64
# OverallCond      1100 non-null int64
# YearBuilt        1100 non-null int64
# YearRemodAdd     1100 non-null int64
# RoofStyle        1100 non-null object
# ...

# %%
columns_to_drop = ["MiscFeature","Fence","PoolQC","FireplaceQu" ,
                   "LotFrontage","Alley","MasVnrType","MasVnrArea" 
                   ,"BsmtQual","BsmtCond","BsmtExposure"
                   ,"BsmtFinType1","BsmtFinType2","GarageType",
                   "GarageYrBlt","GarageFinish","GarageQual"
                   ,"GarageCond"]

# %%
data_clean1 = dataframe.drop(columns_to_drop,axis=1)

# %%
print(data_clean1.shape)
data_clean1.info()
# Out:
# (1100, 63)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 63 columns):
# Id               1100 non-null int64
# MSSubClass       1100 non-null int64
# MSZoning         1100 non-null object
# LotArea          1100 non-null int64
# Street           1100 non-null object
# LotShape         1100 non-null object
# LandContour      1100 non-null object
# Utilities        1100 non-null object
# LotConfig        1100 non-null object
# LandSlope        1100 non-null object
# Neighborhood     1100 non-null object
# Condition1       1100 non-null object
# Condition2       1100 non-null object
# BldgType         1100 non-null object
# HouseStyle       1100 non-null object
# OverallQual      1100 non-null int64
# OverallCond      1100 non-null int64
# YearBuilt        1100 non-null int64
# YearRemodAdd     1100 non-null int64
# RoofStyle        1100 non-null object
# RoofMatl         1100 non-null object
# Exterior1st      1100 non-null object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for c_name in data_clean1.columns:
    
    if(data_clean1[c_name].dtype == "object" ):
        data_clean1[c_name] = le.fit_transform(data_clean1[c_name])

# %%
def corelation_matrix(df):
    f = plt.figure(figsize=(19, 15))
    plt.matshow(df.corr(), fignum=f.number)
    plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
    plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    plt.title('Correlation Matrix', fontsize=16);

# %%
corelation_matrix(data_clean1)

# %%
sales_corma = data_clean1.corr()["SalePrice"]

# %%
col_drop = []
for col in data_clean2.columns:
    if ( sales_corma[col] <= 0.5 ):
        col_drop.append(col)
        

data_clean2 = data_clean1.drop(col_drop,axis=1)

# %%
data_clean2.head()
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0            7       2003          2003          856       856       1710
# 1            6       1976          1976         1262      1262       1262
# 2            7       2001          2002          920       920       1786
# 3            7       1915          1970          756       961       1717
# 4            8       2000          2000         1145      1145       2198
#
#    FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice
# 0         2             8           2         548     208500
# 1         2             6           2         460     181500
# 2         2             6           2         608     223500
# 3         1             7           3         642     140000
# 4         2             9           3         836     250000

# %%
corelation_matrix(data_clean2)

# %%
X_train = np.array(data_clean2.values[:700,:-1])
Y_train = np.array(data_clean2.values[:700,-1])

X_test = np.array(data_clean2.values[700:,:-1])
Y_test = np.array(data_clean2.values[700:,-1])

X = np.array(data_clean2.values[:,:-1])
Y = np.array(data_clean2.values[:,-1])

print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
print(X.shape,Y.shape)
# Out:
# (700, 10) (700,)
# (400, 10) (400,)
# (1100, 10) (1100,)

# %%
from sklearn.preprocessing import normalize

# %%
X_train = normalize(X_train)
X_test = normalize(X_test)
X = normalize(X)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr.score(X_test,Y_test)
# Out:
# 0.7548126033251206

# %%
lr.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
