# %%
import cv2 
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
cam = cv2.VideoCapture(0)

# %%
nose_cascade = cv2.CascadeClassifier("Train/third-party/Nose18x15.xml")

# %%
while True:
    ret, frame = cam.read()
    if ret==False:
        print("kuch to galat ho rha hai")
        continue
    
    key_pressed = cv2.waitKey(1)&0xFF #Bitmasking to get last 8 bits
    if key_pressed==ord('q'): #ord-->ASCII Value(8 bit)
        break
    
    noses = nose_cascade.detectMultiScale(frame,1.3,5)
    for (x,y,w,h) in noses:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),3)
        break
    
    cv2.imshow('Nose Detector',frame)
    
cam.release()
cv2.destroyAllWindows()

# %%
cam = cv2.VideoCapture(0)

# %%
eye_cascade = cv2.CascadeClassifier("Train/third-party/frontalEyes35x16.xml")

# %%
while True:
    ret, frame = cam.read()
    if ret==False:
        print("kuch to galat ho rha hai")
        continue
    
    key_pressed = cv2.waitKey(1)&0xFF #Bitmasking to get last 8 bits
    if key_pressed==ord('q'): #ord-->ASCII Value(8 bit)
        break
    
    eyes = eye_cascade.detectMultiScale(frame,1.3,5)
    for (x,y,w,h) in eyes:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),3)
        break
    
    
    
    cv2.imshow('eyes Detector',ovrlay)
    
cam.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-15fb5f15a31e> in <module>
#      16
#      17
# ---> 18     cv2.imshow('eyes Detector',ovrlay)
#      19
#      20 cam.release()
#
# NameError: name 'ovrlay' is not defined

# %%
type(frame)
# Out:
# numpy.ndarray

# %%
cv2.addWeighted?

# %%
glasses = cv2.imread("Train/glasses.png",cv2.IMREAD_UNCHANGED)
#glasses = cv2.cvtColor(glasses,cv2.COLOR_BGR2RGB)
plt.imshow(glasses)

# %%
mustache = cv2.imread("Train/mustache.png",cv2.IMREAD_UNCHANGED)

# %%
kingslayer = cv2.imread("Train/Jamie_Before.jpg",cv2.IMREAD_UNCHANGED)
kingslayer = cv2.cvtColor(kingslayer,cv2.COLOR_BGR2RGBA)
print(kingslayer.shape)
# Out:
# (1024, 733, 4)

# %%
plt.imshow(kingslayer)

# %%
eyes = eye_cascade.detectMultiScale(kingslayer,1.3,5)

# %%
kingslayer.shape
# Out:
# (1024, 733, 4)

# %%
eyes
# Out:
# array([[234, 361, 286, 131],
#        [189, 334, 371, 170]], dtype=int32)

# %%
h = eyes[1][0] - eyes[1][3]
b = eyes[1][2] - eyes[1][1]
print(l)
print(b)
# Out:
# 21
# 37

# %%
new_glasses = cv2.resize(glasses ,dsize = (371,170))

# %%
plt.imshow(new_glasses)

# %%
new_glasses.shape
# Out:
# (170, 371, 4)

# %%
kingslayer[eyes[0][2]:eyes[0][1],eyes[0][0]:eyes[0][3]]
# Out:
# array([], shape=(75, 0, 4), dtype=uint8)

# %%
plt.imshow(kingslayer[334:334+170,191:191+371])

# %%
kingslayer[334:334+170,191:191+371] = new_glasses[:,:,:3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-189-24d6dc485a5b> in <module>
# ----> 1 kingslayer[334:334+170,191:191+371] = new_glasses[:,:,:3]
#
# ValueError: could not broadcast input array from shape (170,371,3) into shape (170,371,4)

# %%
plt.imshow(new_glasses[:,:,:])

# %%
plt.imshow(cv2.addWeighted(new_glasses,0.8,kingslayer[334:334+170,191:191+371],1,0))

# %%
cv2.addWeighted(kingslayer[334:334+170,191:191+371],0.2,new_glasses,0.5,0)
# Out:
# array([[[ 9,  3,  2, 51],
#         [10,  4,  2, 51],
#         [10,  5,  2, 51],
#         ...,
#         [14,  9,  6, 51],
#         [16, 11,  8, 51],
#         [19, 13, 10, 51]],
#
#        [[11,  5,  3, 51],
#         [10,  5,  2, 51],
#         [10,  5,  2, 51],
#         ...,
#         [11,  5,  2, 51],
#         [13,  7,  4, 51],
#         [14,  8,  5, 51]],
#
#        [[12,  7,  5, 51],
#         [12,  7,  5, 51],
#         [12,  7,  4, 51],
#         ...,
#         [13,  8,  5, 51],
#         [10,  4,  1, 51],
#         [ 9,  3,  0, 51]],
#
#        ...,
#        [[32, 23, 18, 51],
#         [31, 22, 17, 51],
#         [30, 21, 16, 51],
#         ...,
#         [39, 29, 23, 51],
#         [40, 30, 21, 51],
#         [43, 32, 21, 51]],
#
#        [[32, 23, 18, 51],
#         [30, 21, 16, 51],
#         [30, 20, 16, 51],
#         ...,
#         [37, 27, 20, 51],
#         [41, 30, 21, 51],
#         [44, 33, 21, 51]],
#
#        [[32, 23, 17, 51],
#         [29, 20, 14, 51],
#         [29, 20, 15, 51],
#         ...,
#         [37, 27, 20, 51],
#         [41, 31, 21, 51],
#         [44, 33, 22, 51]]], dtype=uint8)
