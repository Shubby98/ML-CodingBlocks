# %%
import cv2 
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
eye_cascade = cv2.CascadeClassifier("Train/third-party/frontalEyes35x16.xml")

# %%
glasses = cv2.imread("Train/glasses.png",cv2.IMREAD_UNCHANGED)
glasses = cv2.cvtColor(glasses,cv2.COLOR_BGR2RGBA)
plt.imshow(glasses)

# %%
kingslayer = cv2.imread("Train/Jamie_Before.jpg",cv2.IMREAD_UNCHANGED)
kingslayer = cv2.cvtColor(kingslayer,cv2.COLOR_BGR2RGBA)
print(kingslayer.shape)
plt.imshow(kingslayer)
# Out:
# (1024, 733, 4)

# %%
eyes = eye_cascade.detectMultiScale(kingslayer,5,5)

# %%
print(len(eyes))
x = eyes[0][0]
y = eyes[0][1]
w = eyes[0][2]
h = eyes[0][3]
new_glasses = cv2.resize(glasses ,dsize = (w,h))
plt.imshow(new_glasses)
# Out:
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-5833f4fd5cad> in <module>
#       1 print(len(eyes))
# ----> 2 x = eyes[0][0]
#       3 y = eyes[0][1]
#       4 w = eyes[0][2]
#       5 h = eyes[0][3]
#
# IndexError: tuple index out of range

# %%
plt.imshow(kingslayer[y:y+h,x:x+w])

# %%
plt.imshow(new_glasses[:,:,3])

# %%
alpha = new_glasses[:,:,3]/255
inverted_alpha = 1 - alpha
plt.imshow(inverted_alpha)

# %%
(X,Y) = alpha.shape

for i in range(X):
    for j in range(Y):
        if(alpha[i,j]):
            kingslayer[y+i,x+j,:3] = new_glasses[i,j,:3]

# %%
plt.figure(figsize=(15,15))
plt.imshow(kingslayer)

# %%
nose_cascade = cv2.CascadeClassifier("Train/third-party/Nose18x15.xml")

# %%
mustache = cv2.imread("Train/mustache.png",cv2.IMREAD_UNCHANGED)
mustache = cv2.cvtColor(mustache,cv2.COLOR_BGR2RGBA)
plt.imshow(mustache)

# %%
noses = nose_cascade.detectMultiScale(kingslayer,10,5)

# %%
noses
# Out:
# array([[284, 461, 180, 150]], dtype=int32)

# %%
x1 = noses[0][0]
y1 = noses[0][1]
w1 = noses[0][2]
h1 = noses[0][3]
plt.figure(figsize=(7,7))
plt.imshow(kingslayer[y1:y1+h1,x1:x1+w1])

# %%
noses
# Out:
# array([[284, 461, 180, 150]], dtype=int32)

# %%
x1 = noses[0][0]
y1 = noses[0][1]
w1 = noses[0][2]
h1 = noses[0][3]

# %%
new_mustache = cv2.resize(mustache ,dsize = (w1,(h1//2)))

# %%
plt.imshow(new_mustache)

# %%
alpha1 = new_mustache[:,:,3]/255
inverted_alpha1 = 1 - alpha1
plt.imshow(inverted_alpha1)

# %%
(X1,Y1) = alpha1.shape

for j in range(Y1):
    for i in range(X1):
        if(alpha1[i,j]):
            kingslayer[y1+i+(2*h1//4),x1+j,:3] = new_mustache[i,j,:3]

# %%
plt.figure(figsize=(15,15))
plt.imshow(kingslayer)

# %%
eye_cascade = cv2.CascadeClassifier("Train/third-party/frontalEyes35x16.xml")
glasses = cv2.imread("Train/glasses.png",cv2.IMREAD_UNCHANGED)
glasses = cv2.cvtColor(glasses,cv2.COLOR_BGR2RGBA)
kingslayer = cv2.imread("Train/Jamie_Before.jpg",cv2.IMREAD_UNCHANGED)
kingslayer = cv2.cvtColor(kingslayer,cv2.COLOR_BGR2RGBA)
print(kingslayer.shape)
eyes = eye_cascade.detectMultiScale(kingslayer,1.5,5)
x = eyes[0][0]
y = eyes[0][1]
w = eyes[0][2]
h = eyes[0][3]
new_glasses = cv2.resize(glasses ,dsize = (w,h))
alpha = new_glasses[:,:,3]/255
inverted_alpha = 1 - alpha
# Out:
# (1024, 733, 4)

# %%
eye_cascade = cv2.CascadeClassifier("Train/third-party/frontalEyes35x16.xml")
glasses = cv2.imread("Train/glasses.png",cv2.IMREAD_UNCHANGED)
glasses = cv2.cvtColor(glasses,cv2.COLOR_BGR2RGBA)
kingslayer = cv2.imread("Train/Jamie_Before.jpg",cv2.IMREAD_UNCHANGED)
kingslayer = cv2.cvtColor(kingslayer,cv2.COLOR_BGR2RGBA)
print(kingslayer.shape)
eyes = eye_cascade.detectMultiScale(kingslayer,1.5,5)
x = eyes[0][0]
y = eyes[0][1]
w = eyes[0][2]
h = eyes[0][3]
new_glasses = cv2.resize(glasses ,dsize = (w,h))
alpha = new_glasses[:,:,3]/255
inverted_alpha = 1 - alpha



nose_cascade = cv2.CascadeClassifier("Train/third-party/Nose18x15.xml")
mustache = cv2.imread("Train/mustache.png",cv2.IMREAD_UNCHANGED)
mustache = cv2.cvtColor(mustache,cv2.COLOR_BGR2RGBA)
plt.imshow(mustache)
noses = nose_cascade.detectMultiScale(kingslayer,6,3)
x1 = noses[0][0]
y1 = noses[0][1]
w1 = noses[0][2]
h1 = noses[0][3]
plt.figure(figsize=(7,7))
plt.imshow(kingslayer[y1:y1+h1,x1:x1+w1])
new_mustache = cv2.resize(mustache ,dsize = ((23*w1//16),(15*h1//16)))
alpha1 = new_mustache[:,:,3]/255
inverted_alpha1 = 1 - alpha1
plt.imshow(inverted_alpha1)
# Out:
# (1024, 733, 4)

# %%
(X1,Y1) = alpha1.shape

for i in range(X1):
    for j in range(Y1):
        if(alpha1[i,j]):
            kingslayer[y1+i+(7*h1//16),x1+j+(-3*w1//16),:3] = new_mustache[i,j,:3]
            
plt.figure(figsize=(15,15))
plt.imshow(kingslayer)

# %%
result = pd.DataFrame(kingslayer,columns = ["Channel 1","Channel 2","Channel 3"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-f815fdb1bf88> in <module>
# ----> 1 result = pd.DataFrame(kingslayer,columns = ["Channel 1","Channel 2","Channel 3"])
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     359             else:
#     360                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 361                                          copy=copy)
#     362         elif isinstance(data, (list, types.GeneratorType)):
#     363             if isinstance(data, types.GeneratorType):
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     511         # by definition an array here
#     512         # the dtypes will be coerced to a single dtype
# --> 513         values = _prep_ndarray(values, copy=copy)
#     514
#     515         if dtype is not None:
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in _prep_ndarray(values, copy)
#    6255         values = values.reshape((values.shape[0], 1))
#    6256     elif values.ndim != 2:
# -> 6257         raise ValueError('Must pass 2-d input')
#    6258
#    6259     return values
#
# ValueError: Must pass 2-d input

# %%
kingslayer.shape
# Out:
# (1024, 733, 4)

# %%
np.flatiter(kingslayer[:,:,:3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-d04b99aca6ed> in <module>
# ----> 1 np.flatiter(kingslayer[:,:,:3])
#
# TypeError: cannot create 'numpy.flatiter' instances

# %%
print(tyrin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-9b5d7c77630a> in <module>
#       1
# ----> 2 print(tyrin)
#
# NameError: name 'tyrin' is not defined

# %%
chain = cv2.imread("Train/Gold-Chain.png",cv2.IMREAD_UNCHANGED)

# %%
chain = cv2.cvtColor(chain,cv2.COLOR_BGR2RGBA)
plt.imshow(chain)

# %%
face_cascade = cv2.CascadeClassifier("Train/haarcascade_frontalface_alt.xml")

# %%
faces = face_cascade.detectMultiScale(kingslayer,1.3,5)

# %%
x2 = faces[0][0]
y2 = faces[0][1]
w2 = faces[0][2]
h2 = faces[0][3]
print(faces)
# Out:
# [[129 231 490 490]]

# %%
plt.imshow(kingslayer[y:y+h,x:x+h])

# %%
new_chain = cv2.resize(chain,dsize=(w2,h2))

# %%
alpha2 = new_chain[:,:,3]/255

# %%
(X2,Y2) = alpha2.shape
print(kingslayer.shape)
l=kingslayer.shape[0]
b = kingslayer.shape[1]
# Out:
# (1024, 733, 4)

# %%
for i in range(X2):
    for j in range(Y2):
        if(y2+h2+j<l and x2+w2+i<b):
            kingslayer[y2+h2+j,x2+w2+i,:3] = new_chain[j,i,:3]

# %%
print(new_chain.shape)
plt.imshow(new_chain)
# Out:
# (490, 490, 4)

# %%
plt.figure(figsize=(10,10))
plt.imshow(kingslayer)

# %%
plt.imshow(alpha2)
