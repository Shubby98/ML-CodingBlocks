# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(10)
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
y = (x-5)**2
type(y)
# Out:
# numpy.ndarray

# %%
plt.plot(y)
plt.show()

# %% [markdown]
# # Gradient Descent Algo

# %%
x1 = 
steps = 1
learning_rate = 0.1 

plt.plot(x,y)

while(steps<=30):
    x1 = x1 - learning_rate*(2*(x1-5))
    
    error = (x1 - 5)**2
    plt.scatter(x1,error)
    print("X %.4f ,Error %.4f "%(x1,error))
    steps += 1
    
plt.show()
# Out:
# X 1.0000 ,Error 16.0000
# X 1.8000 ,Error 10.2400
# X 2.4400 ,Error 6.5536
# X 2.9520 ,Error 4.1943
# X 3.3616 ,Error 2.6844
# X 3.6893 ,Error 1.7180
# X 3.9514 ,Error 1.0995
# X 4.1611 ,Error 0.7037
# X 4.3289 ,Error 0.4504
# X 4.4631 ,Error 0.2882
# X 4.5705 ,Error 0.1845
# X 4.6564 ,Error 0.1181
# X 4.7251 ,Error 0.0756
# X 4.7801 ,Error 0.0484
# X 4.8241 ,Error 0.0309
# X 4.8593 ,Error 0.0198
# X 4.8874 ,Error 0.0127
# X 4.9099 ,Error 0.0081
# X 4.9279 ,Error 0.0052
# X 4.9424 ,Error 0.0033
# X 4.9539 ,Error 0.0021
# X 4.9631 ,Error 0.0014
# X 4.9705 ,Error 0.0009
# X 4.9764 ,Error 0.0006
# X 4.9811 ,Error 0.0004
# X 4.9849 ,Error 0.0002
# X 4.9879 ,Error 0.0001
# X 4.9903 ,Error 0.0001
# X 4.9923 ,Error 0.0001
# X 4.9938 ,Error 0.0000
